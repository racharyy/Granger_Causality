# %%
from causalgraphicalmodels import CausalGraphicalModel as cm

# %%
model = cm(nodes=["BMS","GS","SE","SI"],edges=[("BMS","SE"),("BMS","SI"),("GS","SE"),("GS","SI"),("SE","SI")])

# %%
model.draw()

# %%
import graphviz as gv

# %%
dot = gv.Digraph()
dot.node("C")
dot.node("L", style='filled')
dot.node("SE", style='filled')
dot.node("PSI", style='dashed',shape='box')
edge_list = [("C","SE"),("C","PSI"),("L","SE"),("L","PSI"),("SE","PSI")]
for edge in edge_list:
    dot.edge(edge[0],edge[1])

# %%
dot

# %%
import pylab

# %%
filename = dot.render(filename='Plots/gm')

# %%
pylab.savefig(filename,format = 'png',dpi=300)

# %%
pylab.close()

# %%
dot
